# %% [markdown]
# <a href="https://colab.research.google.com/github/Ana12399/IMC/blob/main/registroestudiantes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre = []
apellido = []
materia = []

# %%
alumnos = int(input("Ingrese la cantidad de alumnos: "))
for i in range(alumnos):
  nombre.append(input("Ingrese el nombre del alumno: "))
  apellido.append(input("Ingrese el apellido del alumno: "))
  materias = int(input("Ingrese la cantidad de materias del alumno: "))
  temp = []
  for j in range(materias):
    temp.append(input("Ingrese la materia: "))
  materia.append(temp)
# Out:
# Ingrese la cantidad de alumnos: 4
# Ingrese el nombre del alumno: jose
# Ingrese el apellido del alumno: callejas
# Ingrese la cantidad de materias del alumno: 3
# Ingrese la materia: historia
# Ingrese la materia: quimica
# Ingrese la materia: fisica
# Ingrese el nombre del alumno: juan
# Ingrese el apellido del alumno: melgar
# Ingrese la cantidad de materias del alumno: 1
# Ingrese la materia: historia
# Ingrese el nombre del alumno: carolina
# Ingrese el apellido del alumno: perez
# Ingrese la cantidad de materias del alumno: 2
# Ingrese la materia: quimica
# Ingrese la materia: matematica
# Ingrese el nombre del alumno: karla
# Ingrese el apellido del alumno: martinez
# Ingrese la cantidad de materias del alumno: 4
# Ingrese la materia: historia
# Ingrese la materia: quimica
# Ingrese la materia: fisica
# Ingrese la materia: matematica

# %%
import numpy as np
import pandas as pd
estudiantes = pd.DataFrame({'key': np.random.choice(10000, size=alumnos, replace=False), 'Nombre': nombre, 'Apellido': apellido, 'Materias': materia})
estudiantes
# Out:
#     key    Nombre  Apellido                                 Materias
# 0   638      jose  callejas              [historia, quimica, fisica]
# 1  2812      juan    melgar                               [historia]
# 2  1443  carolina     perez                    [quimica, matematica]
# 3  3081     karla  martinez  [historia, quimica, fisica, matematica]

# %%
key = []

import numpy as np
np.random.choice(10000, size=alumnos, replace=False)
# Out:
# array([8214, 3644, 9740, 7263])

# %%
# Guardar base en un csv
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
estudiantes.to_csv('/content/drive/MyDrive/Colab Notebooks/estudiantes.csv' , index=False)
